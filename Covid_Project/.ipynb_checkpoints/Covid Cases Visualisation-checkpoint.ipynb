# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates
import seaborn as sns
import datetime 
import requests
import folium
#import squarify
#import plotly.offline as py
#import plotly_express as px

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
#from statsmodels.tsa.arima_model import ARIMA
#from fbprophet import Prophet
#from fbprophet.plot import plot_plotly, add_changepoints_to_plot

from IPython.display import Image
warnings.filterwarnings('ignore')
# %matplotlib inline

age_details = pd.read_csv('AgeGroupDetails.csv')
india_covid_19 = pd.read_csv('covid_19_india.csv')
hospital_beds = pd.read_csv('HospitalBedsIndia.csv')
individual_details = pd.read_csv('IndividualDetails.csv')

ICMR_labs = pd.read_csv('ICMRTestingLabs.csv')
state_testing = pd.read_csv('StatewiseTestingDetails.csv')
population = pd.read_csv('population_india_census2011.csv')

confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv')

india_covid_19['Date'] = pd.to_datetime(india_covid_19['Date'],dayfirst = True)
state_testing['Date'] = pd.to_datetime(state_testing['Date'])

# %%
labels = list(age_details['AgeGroup'])
sizes = list(age_details['TotalCases'])

explode = []

for i in labels:
    explode.append(0.05)
    
plt.figure(figsize= (15,10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=9, explode =explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('India - Age Group wise Distribution',fontsize = 20)
plt.axis('equal')  
plt.tight_layout()

# %% [markdown]
# The age group which is most affected is less than 50. Most number of cases occur in this age group but the virus affects the health of elderly the most.

# %% [markdown]
# ## Age Group Analysis

# %%
labels = ['Male', 'Female']
sizes = []
sizes.append(list(individual_details['gender'].value_counts())[0])
sizes.append(list(individual_details['gender'].value_counts())[1])

explode = (0.1, 0)
colors = ['#66b3ff','#ff9999']

plt.figure(figsize= (15,10))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)

plt.title('Percentage of Gender (Ignoring the Missing Values)',fontsize = 20)
plt.axis('equal')
plt.tight_layout()

# %% [markdown]
# Men are affected more than women (majority of the gender details is missing in the dataset)

# %%
dates = list(confirmed_df.columns[4:])
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]

df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()

k = df1[df1['Country/Region']=='India'].loc[:,'1/30/20':]
india_confirmed = k.values.tolist()[0] 

k = df2[df2['Country/Region']=='India'].loc[:,'1/30/20':]
india_deaths = k.values.tolist()[0] 

k = df3[df3['Country/Region']=='India'].loc[:,'1/30/20':]
india_recovered = k.values.tolist()[0] 

plt.figure(figsize= (15,10))
plt.xticks(rotation = 90 ,fontsize = 11)
plt.yticks(fontsize = 10)
plt.xlabel("Dates",fontsize = 20)
plt.ylabel('Total cases',fontsize = 20)
plt.title("Total Confirmed, Active, Death in India" , fontsize = 20)

ax1 = plt.plot_date(y= india_confirmed,x= dates_india,label = 'Confirmed',linestyle ='-',color = 'b')
ax2 = plt.plot_date(y= india_recovered,x= dates_india,label = 'Recovered',linestyle ='-',color = 'g')
ax3 = plt.plot_date(y= india_deaths,x= dates_india,label = 'Death',linestyle ='-',color = 'r')
plt.legend();

# %%
state_cases = india_covid_19.groupby('State/UnionTerritory')['Confirmed','Deaths','Cured'].max().reset_index()
state_cases.sort_values('Confirmed', ascending= False).fillna(0).style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Blues',subset=["Deaths"])\
                        .background_gradient(cmap='Blues',subset=["Cured"])
# Out:
# <style  type="text/css" >
#     #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow1_col1 {
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow1_col2 {
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow1_col3 {
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow2_col1 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow2_col2 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow2_col3 {
#             background-color:  #56a0ce;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow3_col1 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow3_col2 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow3_col3 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow4_col1 {
#             background-color:  #bad6eb;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow4_col2 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow4_col3 {
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow5_col1 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow5_col2 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow5_col3 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow6_col1 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow6_col2 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow6_col3 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow7_col1 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow7_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow7_col3 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow8_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow8_col2 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow8_col3 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow9_col1 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow9_col2 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow9_col3 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow10_col1 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow10_col2 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow10_col3 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow11_col1 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow11_col2 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow11_col3 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow12_col1 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow12_col2 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow12_col3 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow13_col1 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow13_col2 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow13_col3 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow14_col1 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow14_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow14_col3 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow15_col1 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow15_col2 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow15_col3 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow16_col1 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow16_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow16_col3 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow17_col1 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow17_col2 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow17_col3 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow18_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow18_col2 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow18_col3 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow19_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow19_col2 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_dd633e60_eb95_11ea_9f6a_482ae345bf8arow19_col3 {
#             background-color:  #ebf3fb;

# %%
# 'covid_19_india.csv' contains cured, deaths and confirmed cases on a day-to-day basis.
cases = pd.read_csv("covid_19_india.csv")
cases.head()


# It can provide us the ratio or rate or percentage of positive cases per population statewise.
popul = pd.read_csv("population_india_census2011.csv")
popul
# Out:
#     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# 14   15                                     Assam    31205576
# 15   16                                    Punjab    27743338
# 16   17                              Chhattisgarh    25545198
# 17   18                                   Haryana    25351462
# 18   19                               Uttarakhand    10086292
# 19   20                          Himachal Pradesh     6864602
# 20   21                                   Tripura     3673917
# 21   22                                 Meghalaya     2966889
# 22   23                                   Manipur     2570390
# 23   24                                  Nagaland     1978502
# 24   25                                       Goa     1458545
# 25   26                         Arunachal Pradesh     1383727
# 26   27                                   Mizoram     1097206
# 27   28                                    Sikkim      610577
# 28   29                                     Delhi    16787941
# 29   30                         Jammu and Kashmir    12267032
# 30   31                                Puducherry     1247953
# 31   32                                Chandigarh     1055450
# 32   33  Dadra and Nagar Haveli and Daman and Diu      585764
# 33   34               Andaman and Nicobar Islands      380581
# 34   35                                    Ladakh      274000
# 35   36                               Lakshadweep       64473
#
#     Rural population  Urban population                         Area  \
# 0          155317278          44495063   240,928 km2 (93,023 sq mi)
# 1           61556074          50818259  307,713 km2 (118,809 sq mi)
# 2           92341436          11758016    94,163 km2 (36,357 sq mi)
# 3           62183113          29093002    88,752 km2 (34,267 sq mi)
# 4           52557404          20069405  308,245 km2 (119,014 sq mi)
# 5           37229590          34917440   130,058 km2 (50,216 sq mi)
# 6           51500352          17048085  342,239 km2 (132,139 sq mi)
# 7           37469335          23625962   191,791 km2 (74,051 sq mi)
# 8           34694609          25745083   196,024 km2 (75,685 sq mi)
# 9           34966693          14610410   162,968 km2 (62,922 sq mi)
# 10          34970562           7003656   155,707 km2 (60,119 sq mi)
# 11          21395009          13608665   112,077 km2 (43,273 sq mi)
# 12          17471135          15934926    38,863 km2 (15,005 sq mi)
# 13          25055073           7933061    79,714 km2 (30,778 sq mi)
# 14          26807034           4398542    78,438 km2 (30,285 sq mi)
# 15          17344192          10399146    50,362 km2 (19,445 sq mi)
# 16          19607961           5937237   135,191 km2 (52,198 sq mi)
# 17          16509359           8842103    44,212 km2 (17,070 sq mi)
# 18           7036954           3049338    53,483 km2 (20,650 sq mi)
# 19           6176050            688552    55,673 km2 (21,495 sq mi)
# 20           2712464            961453     10,486 km2 (4,049 sq mi)
# 21           2371439            595450     22,429 km2 (8,660 sq mi)
# 22           1793875            776515     22,327 km2 (8,621 sq mi)
# 23           1407536            570966     16,579 km2 (6,401 sq mi)
# 24            551731            906814      3,702 km2 (1,429 sq mi)
# 25           1066358            317369    83,743 km2 (32,333 sq mi)
# 26            525435            571771     21,081 km2 (8,139 sq mi)
# 27            456999            153578      7,096 km2 (2,740 sq mi)
# 28            419042          16368899        1,484 km2 (573 sq mi)
# 29           9064220           3202812   125,535 km2 (48,469 sq mi)
# 30            395200            852753          479 km2 (185 sq mi)
# 31             28991           1026459           114 km2 (44 sq mi)
# 32            243510            342254          603 km2 (233 sq mi)
# 33            237093            143488      8,249 km2 (3,185 sq mi)
# 34             43840            230160    96,701 km2 (37,336 sq mi)
# 35             14141             50332            32 km2 (12 sq mi)
#
#                       Density  Gender Ratio
# 0       828/km2 (2,140/sq mi)           912
# 1         365/km2 (950/sq mi)           929
# 2     1,102/km2 (2,850/sq mi)           918
# 3     1,029/km2 (2,670/sq mi)           953
# 4         236/km2 (610/sq mi)           931
# 5       555/km2 (1,440/sq mi)           996
# 6         201/km2 (520/sq mi)           928
# 7         319/km2 (830/sq mi)           973
# 8         308/km2 (800/sq mi)           919
# 9         303/km2 (780/sq mi)           993
# 10        269/km2 (700/sq mi)           979
# 11        312/km2 (810/sq mi)           988
# 12      859/km2 (2,220/sq mi)          1084
# 13      414/km2 (1,070/sq mi)           948
# 14      397/km2 (1,030/sq mi)           954
# 15      550/km2 (1,400/sq mi)           895
# 16        189/km2 (490/sq mi)           991
# 17      573/km2 (1,480/sq mi)           879
# 18        189/km2 (490/sq mi)           963
# 19        123/km2 (320/sq mi)           972
# 20        350/km2 (910/sq mi)           960
# 21        132/km2 (340/sq mi)           989
# 22        122/km2 (320/sq mi)           992
# 23        119/km2 (310/sq mi)           931
# 24      394/km2 (1,020/sq mi)           973
# 25          17/km2 (44/sq mi)           938
# 26         52/km2 (130/sq mi)           976
# 27         86/km2 (220/sq mi)           890
# 28  11,297/km2 (29,260/sq mi)           868
# 29         98/km2 (250/sq mi)           890
# 30    2,598/km2 (6,730/sq mi)          1037
# 31   9,252/km2 (23,960/sq mi)           818
# 32      970/km2 (2,500/sq mi)           711
# 33         46/km2 (120/sq mi)           876
# 34        2.8/km2 (7.3/sq mi)           853
# 35    2,013/km2 (5,210/sq mi)           946
